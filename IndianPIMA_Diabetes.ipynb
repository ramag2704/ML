# %% [markdown]
# <b>Diabetes Prediction</b>
# <p>
# Diabetes, is a group of metabolic disorders in which there are high blood sugar levels over a prolonged period.
# Symptoms of high blood sugar include frequent urination, increased thirst, and increased hunger.
# If left untreated, diabetes can cause many complications. Acute complications can include diabetic ketoacidosis,
# hyperosmolar hyperglycemic state, or death. Serious long-term complications include cardiovascular disease,
# stroke, chronic kidney disease, foot ulcers, and damage to the eyes.This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases.
#
# The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database.
# In particular, all patients here are females at least 21 years old of Pima Indian heritage.
# </p>
#
# <b>Objective</b>
# <p>
# We will try to build a machine learning model to accurately predict whether or not the patients in the dataset
# have diabetes or not?
# </p>
#
# <b>Data</b>
# <p>
# The datasets consists of several medical predictor variables and one target variable, Outcome. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.
# <p>
#
# <b>Pregnancies:</b> Number of times pregnant
# <p><b>Glucose:</b> Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# <p><b>BloodPressure:</b> Diastolic blood pressure (mm Hg)
# <p><b>SkinThickness:</b> Triceps skin fold thickness (mm)
# <p><b>Insulin:</b> 2-Hour serum insulin (mu U/ml)
# <p><b>BMI:</b> Body mass index (weight in kg/(height in m)^2)
# <p><b>DiabetesPedigreeFunction:</b> Diabetes pedigree function
# <p><b>Age:</b>Age (years)
# <p><b>Outcome:</b> Class variable (0 or 1)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
diabetes = pd.read_csv('diabetes.csv')

diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %% [markdown]
# <b>First 6 samples</b>

# %%
first = diabetes.head(6)
first
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %% [markdown]
# <b>Last 7 samples</b>

# %%
last = diabetes.tail(7)
last
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# <b>Summary/Quick overview of the Dataset<b>

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# <b>Transpose Diabetes Data</b>

# %%
diabetes.transpose()
# Out:
#                               0       1        2       3        4        5    \
# Pregnancies                 6.000   1.000    8.000   1.000    0.000    5.000
# Glucose                   148.000  85.000  183.000  89.000  137.000  116.000
# BloodPressure              72.000  66.000   64.000  66.000   40.000   74.000
# SkinThickness              35.000  29.000    0.000  23.000   35.000    0.000
# Insulin                     0.000   0.000    0.000  94.000  168.000    0.000
# BMI                        33.600  26.600   23.300  28.100   43.100   25.600
# DiabetesPedigreeFunction    0.627   0.351    0.672   0.167    2.288    0.201
# Age                        50.000  31.000   32.000  21.000   33.000   30.000
# Outcome                     1.000   0.000    1.000   0.000    1.000    0.000
#
#                              6        7        8        9    ...      758  \
# Pregnancies                3.000   10.000    2.000    8.000  ...    1.000
# ...

# %% [markdown]
# <b>Point Five Summary</b>

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# <b>Data Visualization</b>

# %% [markdown]
# <b>Distribution of Diabetes </b>
# <p>Age and Blood Pressure are skewed

# %%
sns.distplot(diabetes[['Pregnancies']], hist=False, rug=True)
sns.distplot(diabetes[['Age']], hist=False, rug=True)
sns.distplot(diabetes[['BMI']], hist=False, rug=True)
sns.distplot(diabetes[['Glucose']], hist=False, rug=True)
sns.distplot(diabetes[['BloodPressure']], hist=False, rug=True)
plt.show()
for col in diabetes.columns:
  sns.distplot(diabetes[[col]], hist=False, rug=True)

# %% [markdown]
# <b>Histogram</b>
# <p>Plotting for all columns to predict Diabetes

# %%
for col in diabetes.columns:
    plt.hist(diabetes[col], 5, facecolor='green')
    #hist = diabetes[col].hist(bins=10)
    plt.xlabel(col)
       
    print("Plotting for column {}".format(col))
    plt.show()
# Out:
# Plotting for column Pregnancies
# Plotting for column Glucose
# Plotting for column BloodPressure
# Plotting for column SkinThickness
# Plotting for column Insulin
# Plotting for column BMI
# Plotting for column DiabetesPedigreeFunction
# Plotting for column Age
# Plotting for column Outcome

# %% [markdown]
# <b>Histogram - Group by Outcome</b>

# %%
diabetes.groupby('Outcome').hist(figsize=(9, 9))
# Out:
# Outcome
# 0    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object

# %% [markdown]
# <b>Comparison of BMI and Pregnancies against the Outcome of Diabetes</b>

# %%
diabetes = diabetes.head(10)
fig, ax = plt.subplots()
diabetes.plot.bar(x = 'Outcome', y = ['BMI', 'Pregnancies'], rot = 40, ax = ax)
plt.show()

# %% [markdown]
# <b>Checking for Null Values in Diabetes Data</b>

# %%
diabetes.isnull().values.any() #looks like we don't have any nulls
# Out:
# False

# %% [markdown]
# <b>Box Plotting for different attributes and Outliers</b>

# %%
diabetes.boxplot(by ='Outcome', column =['BMI','Pregnancies'], grid = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022814AACD30>,
# ...
#       dtype=object)

# %%
diabetes.boxplot(by ='Outcome', column =['Glucose','SkinThickness'], grid = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022814F2EDA0>,
# ...
#       dtype=object)

# %%
diabetes.boxplot(by ='Outcome', column =['Age','BloodPressure'], grid = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022815000E80>,
# ...
#       dtype=object)

# %%
diabetes.boxplot(by ='Outcome', column =['SkinThickness','Insulin'], grid = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022813277240>,
# ...
#       dtype=object)

# %% [markdown]
# <b>Scatter Plot for different parameters against the Outcome of Diabetes </b>

# %%
plt.xlabel('Outcome')
bmi=plt.scatter(x=diabetes['BMI'], y=diabetes['Outcome'])
preg=plt.scatter(x=diabetes['Pregnancies'], y=diabetes['Outcome'])
gluc=plt.scatter(x=diabetes['Glucose'], y=diabetes['Outcome'])
age=plt.scatter(x=diabetes['Age'], y=diabetes['Outcome'])
bp=plt.scatter(x=diabetes['BloodPressure'], y=diabetes['Outcome'])
plt.legend((bmi,preg,gluc,age,bp),('BMI', 'Pregnancies', 'Glucose', 'Age', 'BloodPressure'),
           scatterpoints=1,
           loc='center',
           ncol=3,
           fontsize=8)

plt.show()

# %% [markdown]
# <b>Adding new columns - Finding logarthamic values for Age, Pragnancies and Insulin parameters</b>
# <p>log of Pregnancies and log of Insulin has Infinite values which are replaced by 0 to have a better visualization of data

# %%
np.seterr(divide='ignore')
pd.set_option('mode.chained_assignment',None)
diabetes['log2_Age'] = np.log2(diabetes['Age'])
diabetes['log2_Insulin'] = np.log2(diabetes['Insulin'])
diabetes['log2_Pregnancies'] = np.log2(diabetes['Pregnancies'])
diabetes['log2_Insulin'] = diabetes['log2_Insulin'].replace([np.inf, -np.inf], 0)
diabetes['log2_Pregnancies'] = diabetes['log2_Pregnancies'].replace([np.inf, -np.inf], 0)
diabetes
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome  log2_Age  log2_Insulin  \
# 0                     0.627   50        1  5.643856      0.000000
# 1                     0.351   31        0  4.954196      0.000000
# ...

# %% [markdown]
# <b>Scatter Plot for new parameters - log of Age, log of Insulin and log of Pregnancies parameters</b>

# %%
plt.xlabel('Outcome')

log2_age=plt.scatter(x=diabetes['log2_Age'], y=diabetes['Outcome'])    
log2_insulin=plt.scatter(x=diabetes['log2_Insulin'], y=diabetes['Outcome'])  
log2_Pregnancies=plt.scatter(x=diabetes['log2_Pregnancies'], y=diabetes['Outcome'])  
plt.legend((log2_age,log2_insulin,log2_Pregnancies),('log2_Age', 'log2_Insulin','log2_Pregnancies'),
           scatterpoints=1,
           loc='center',
           ncol=3,
           fontsize=8)

plt.show()

# %% [markdown]
# <b>Correlation features and Correlation plotting of different parameters of Diabetes</b>

# %%
 corr = diabetes.corr() # calling the correlation function on the datafrmae
 fig, ax = plt.subplots(figsize=(11,11))
 ax.matshow(corr) # color code the rectangles by correlation value
 plt.xticks(range(len(corr.columns)),corr.columns) # draw x tickmarks
 plt.yticks(range(len(corr.columns)),corr.columns) # draw y tickmarks
 corr
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.223872      -0.157293      -0.754551
# Glucose                      0.223872  1.000000       0.160011       0.079469
# BloodPressure               -0.157293  0.160011       1.000000       0.048614
# SkinThickness               -0.754551  0.079469       0.048614       1.000000
# Insulin                     -0.463945  0.514553       0.049254       0.637260
# BMI                         -0.398816  0.020703      -0.671852       0.522803
# DiabetesPedigreeFunction    -0.360170  0.193676      -0.193327       0.283820
# Age                          0.225499  0.610445       0.490878       0.187328
# Outcome                      0.036860  0.559457       0.278445       0.330323
# log2_Age                     0.247630  0.635244       0.449268       0.166306
# log2_Insulin                -0.701923  0.096986      -0.085431       0.699428
# ...

# %% [markdown]
# <b>Summary</b>
# <p>Out of 768 samples, 268  has diabetes and 500 does not have diabetes.
# <p>SkinThickness, Glucose and Blood Pressure does not have outliers .
# <p>Age and log of Age seem to be correlated and same with Insulin and log of Insulin .
# <p>As the ratio of diabete to non diabetic predictions are not proportional , remedial actions like making equal proportions have to be made.
# For this techniques like Up Sampling / Down sampling should be used and data should be cleaned so that it gives more accurate results.
